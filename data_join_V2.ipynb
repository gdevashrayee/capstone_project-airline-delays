# %%
import pandas as pd

airport_df = pd.read_csv('airports_list.csv')

# %%
airport_df.tail()
# Out:
#     ORIGIN_AIRPORT_ID             DISPLAY_AIRPORT_NAME   ORIGIN_CITY_NAME  \
# 92              15370              Tulsa International          Tulsa, OK
# 93              12264  Washington Dulles International     Washington, DC
# 94              13851                Will Rogers World  Oklahoma City, OK
# 95              12191                  William P Hobby        Houston, TX
# 96              10713               Boise Air Terminal          Boise, ID
#
#                                               NAME
# 92  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US
# 93  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US
# 94  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US
# 95          HOUSTON WILLIAM P HOBBY AIRPORT, TX US
# 96                       BOISE AIR TERMINAL, ID US

# %%
ontime_01_df = pd.read_csv('ONTIME_REPORTING_01.csv')
ontime_01_df.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0      1             6            7                9E   N8694A
# 1      1             7            1                9E   N8970D
# 2      1             8            2                9E   N820AY
# 3      1             9            3                9E   N840AY
# 4      1            10            4                9E   N8969A
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  \
# 0               3280              10397    ATL      Atlanta, GA
# 1               3280              10397    ATL      Atlanta, GA
# 2               3280              10397    ATL      Atlanta, GA
# 3               3280              10397    ATL      Atlanta, GA
# 4               3280              10397    ATL      Atlanta, GA
#
#    DEST_AIRPORT_ID  ... CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME  DISTANCE  \
# 0            11150  ...             47.0                37.0      83.0
# ...

# %%
ontime_02_df = pd.read_csv('ONTIME_REPORTING_04.csv')
print(ontime_02_df)
# Out:
#         MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0           4             5            5                NK   N646NK
# 1           4             6            6                NK   N615NK
# 2           4             7            7                NK   N633NK
# 3           4             8            1                NK   N655NK
# 4           4             9            2                NK   N605NK
# ...       ...           ...          ...               ...      ...
# 612018      4            11            4                YX   N120HQ
# 612019      4            12            5                YX   N418YX
# 612020      4            14            7                YX   N113HQ
# 612021      4            15            1                YX   N420YX
# 612022      4            16            2                YX   N126HQ
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  \
# 0                     779              12953    LGA     New York, NY
# ...

# %%
ontime_03_df = pd.read_csv('ONTIME_REPORTING_07.csv')
print(ontime_03_df)
# Out:
#         MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0           7             8            1                AS   N464AS
# 1           7             8            1                AS   N464AS
# 2           7             8            1                AS   N551AS
# 3           7             8            1                AS   N264AK
# 4           7             8            1                AS   N530AS
# ...       ...           ...          ...               ...      ...
# 659024      7            19            5                F9   N213FR
# 659025      7            19            5                F9   N213FR
# 659026      7            19            5                F9   N213FR
# 659027      7            19            5                F9   N216FR
# 659028      7            19            5                F9   N216FR
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ORIGIN_CITY_NAME  \
# 0                     500              14747    SEA       Seattle, WA
# ...

# %%
ontime_04_df = pd.read_csv('ONTIME_REPORTING_10.csv')
print(ontime_04_df)
# Out:
#         MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0          10             6            7                AA   N905NN
# 1          10             7            1                AA   N932NN
# 2          10             8            2                AA   N910AN
# 3          10             9            3                AA   N963AN
# 4          10            10            4                AA   N972AN
# ...       ...           ...          ...               ...      ...
# 636009     10            21            1                9E   N301PQ
# 636010     10            22            2                9E   N232PQ
# 636011     10            23            3                9E   N937XJ
# 636012     10            24            4                9E   N181PQ
# 636013     10            25            5                9E   N909XJ
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  \
# 0                    2308              14893    SMF   Sacramento, CA
# ...

# %%
airport_weather = pd.read_csv('Airport_Weather_2019.csv')
print(airport_weather)
# Out:
#                                                     NAME        DATE   AWND  \
# 0      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/1/2019   4.70
# 1      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/2/2019   4.92
# 2      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/3/2019   5.37
# 3      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/4/2019  12.08
# 4      ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...    1/5/2019  13.42
# ...                                                  ...         ...    ...
# 38670                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-27   6.04
# 38671                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-28   5.37
# 38672                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-29   7.61
# 38673                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-30   5.82
# 38674                TALLAHASSEE REGIONAL AIRPORT, FL US  2019-12-31   3.58
#
#        PRCP  SNOW
# 0      0.14   0.0
# ...

# %%
df_ontime_reporting=pd.concat([ontime_01_df,ontime_02_df,ontime_03_df,ontime_04_df],axis=0,join="outer")
df_ontime_reporting.tail()
# Out:
#         MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 636009     10            21            1                9E   N301PQ
# 636010     10            22            2                9E   N232PQ
# 636011     10            23            3                9E   N937XJ
# 636012     10            24            4                9E   N181PQ
# 636013     10            25            5                9E   N909XJ
#
#         OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN ORIGIN_CITY_NAME  \
# 636009               5196              13487    MSP  Minneapolis, MN
# 636010               5196              13487    MSP  Minneapolis, MN
# 636011               5196              13487    MSP  Minneapolis, MN
# 636012               5196              13487    MSP  Minneapolis, MN
# 636013               5196              13487    MSP  Minneapolis, MN
#
#         DEST_AIRPORT_ID  ... CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME  DISTANCE  \
# ...

# %%
##df_ontime_reporting.to_csv('ontime_reporting.csv', index=False)

# %%
columns = ["MONTH", "DAY_OF_MONTH","DAY_OF_WEEK","ORIGIN_AIRPORT_ID","DEST_AIRPORT_ID","DEST_CITY_NAME","DEP_TIME","DEP_DELAY_NEW","ARR_TIME","ARR_DELAY_NEW","DEP_DEL15","CANCELLED","DISTANCE","DISTANCE_GROUP"]
df_ontime_reporting_final=df_ontime_reporting[columns]
df_ontime_reporting_final.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  \
# 0      1             6            7              10397            11150
# 1      1             7            1              10397            11150
# 2      1             8            2              10397            11150
# 3      1             9            3              10397            11150
# 4      1            10            4              10397            11150
#
#   DEST_CITY_NAME  DEP_TIME  DEP_DELAY_NEW  ARR_TIME  ARR_DELAY_NEW  DEP_DEL15  \
# 0   Columbus, GA    1643.0            0.0    1720.0            0.0        0.0
# 1   Columbus, GA    1640.0            0.0    1712.0            0.0        0.0
# 2   Columbus, GA    1640.0            0.0    1719.0            0.0        0.0
# 3   Columbus, GA    1640.0            0.0    1717.0            0.0        0.0
# 4   Columbus, GA    1640.0            0.0    1721.0            0.0        0.0
#
#    CANCELLED  DISTANCE  DISTANCE_GROUP
# ...

# %%
df_airport_reporting=pd.merge(airport_df,df_ontime_reporting_final,on='ORIGIN_AIRPORT_ID',how='outer')
df_airport_reporting.head()
# Out:
#    ORIGIN_AIRPORT_ID DISPLAY_AIRPORT_NAME ORIGIN_CITY_NAME  \
# 0              12992          Adams Field  Little Rock, AR
# 1              12992          Adams Field  Little Rock, AR
# 2              12992          Adams Field  Little Rock, AR
# 3              12992          Adams Field  Little Rock, AR
# 4              12992          Adams Field  Little Rock, AR
#
#                                NAME  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0  NORTH LITTLE ROCK AIRPORT, AR US      1             1            2
# 1  NORTH LITTLE ROCK AIRPORT, AR US      1            13            7
# 2  NORTH LITTLE ROCK AIRPORT, AR US      1            13            7
# 3  NORTH LITTLE ROCK AIRPORT, AR US      1            13            7
# 4  NORTH LITTLE ROCK AIRPORT, AR US      1            13            7
#
#    DEST_AIRPORT_ID DEST_CITY_NAME  DEP_TIME  DEP_DELAY_NEW  ARR_TIME  \
# 0            10397    Atlanta, GA    1523.0            0.0    1748.0
# ...

# %%
weather_df = pd.read_csv('Airport_weather_2019.csv')
weather_df.tail()
# Out:
#                                      NAME        DATE  YEAR  MONTH  DAY  \
# 7497  TALLAHASSEE REGIONAL AIRPORT, FL US  2019-10-27  2019     10   27
# 7498  TALLAHASSEE REGIONAL AIRPORT, FL US  2019-10-28  2019     10   28
# 7499  TALLAHASSEE REGIONAL AIRPORT, FL US  2019-10-29  2019     10   29
# 7500  TALLAHASSEE REGIONAL AIRPORT, FL US  2019-10-30  2019     10   30
# 7501  TALLAHASSEE REGIONAL AIRPORT, FL US  2019-10-31  2019     10   31
#
#        AWND  PRCP  SNOW
# 7497   5.59  0.01   NaN
# 7498   2.46  0.00   NaN
# 7499   4.47  0.24   NaN
# 7500   7.16  0.00   NaN
# 7501  11.63  0.18   NaN

# %%
df_airport_weather=pd.merge(airport_df,weather_df,on='NAME',how='inner')
df_airport_weather.tail()
# Out:
#       ORIGIN_AIRPORT_ID DISPLAY_AIRPORT_NAME ORIGIN_CITY_NAME  \
# 5406              10713   Boise Air Terminal        Boise, ID
# 5407              10713   Boise Air Terminal        Boise, ID
# 5408              10713   Boise Air Terminal        Boise, ID
# 5409              10713   Boise Air Terminal        Boise, ID
# 5410              10713   Boise Air Terminal        Boise, ID
#
#                            NAME        DATE  YEAR  MONTH  DAY  AWND  PRCP  \
# 5406  BOISE AIR TERMINAL, ID US  2019-10-27  2019     10   27  6.93  0.00
# 5407  BOISE AIR TERMINAL, ID US  2019-10-28  2019     10   28  6.49  0.00
# 5408  BOISE AIR TERMINAL, ID US  2019-10-29  2019     10   29  7.38  0.01
# 5409  BOISE AIR TERMINAL, ID US  2019-10-30  2019     10   30  5.37  0.00
# 5410  BOISE AIR TERMINAL, ID US  2019-10-31  2019     10   31  4.25  0.00
#
#       SNOW
# 5406   0.0
# 5407   0.0
# 5408   0.4
# 5409   0.0
# 5410   0.0

# %%
df_final=pd.merge(df_airport_reporting,df_airport_weather,on='NAME',how='inner')
df_final.tail()
# Out:
#           ORIGIN_AIRPORT_ID_x DISPLAY_AIRPORT_NAME_x ORIGIN_CITY_NAME_x  \
# 47256538                10713     Boise Air Terminal          Boise, ID
# 47256539                10713     Boise Air Terminal          Boise, ID
# 47256540                10713     Boise Air Terminal          Boise, ID
# 47256541                10713     Boise Air Terminal          Boise, ID
# 47256542                10713     Boise Air Terminal          Boise, ID
#
#                                NAME  MONTH_x  DAY_OF_MONTH  DAY_OF_WEEK  \
# 47256538  BOISE AIR TERMINAL, ID US       10            27            7
# 47256539  BOISE AIR TERMINAL, ID US       10            27            7
# 47256540  BOISE AIR TERMINAL, ID US       10            27            7
# 47256541  BOISE AIR TERMINAL, ID US       10            27            7
# 47256542  BOISE AIR TERMINAL, ID US       10            27            7
#
#           DEST_AIRPORT_ID      DEST_CITY_NAME  DEP_TIME  ...  \
# ...

# %%
df_final.isnull().sum()
# Out:
# ORIGIN_AIRPORT_ID_x              0
# DISPLAY_AIRPORT_NAME_x           0
# ORIGIN_CITY_NAME_x               0
# NAME                             0
# MONTH_x                          0
# DAY_OF_MONTH                     0
# DAY_OF_WEEK                      0
# DEST_AIRPORT_ID                  0
# DEST_CITY_NAME                   0
# DEP_TIME                    925072
# DEP_DELAY_NEW               925687
# ARR_TIME                    967997
# ARR_DELAY_NEW              1080783
# DEP_DEL15                   925687
# CANCELLED                        0
# DISTANCE                         0
# DISTANCE_GROUP                   0
# ORIGIN_AIRPORT_ID_y              0
# DISPLAY_AIRPORT_NAME_y           0
# ORIGIN_CITY_NAME_y               0
# DATE                             0
# YEAR                             0
# MONTH_y                          0
# DAY                              0
# AWND                             0
# PRCP                         21594
# SNOW                      18554069
# ...
